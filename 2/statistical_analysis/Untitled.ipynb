# %%
# Z-test with 2 independent samples. I choose a z-test because sample size exceeds 30

# Ho: The amount of moves has statistical significance on wins or tie as outcome
# Ha: The amount of moves has no statistical sign

# Plot overlapping density subplots and draw dotted line comparing means.

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.weightstats import ztest

# %%
data = pd.read_pickle("./parsed_moves_winslosses_ties.pkl")
data.keys()
# Out:
# dict_keys(['Wins', 'Loss', 'Draw'])

# %%
data["Wins"][:10]
np.std(data["Wins"])
# Out:
# 14.781656452204697

# %%
len(data["Draw"])
# Out:
# 2627228

# %%
# Obtain Z statistic
ztest(data["Wins"], data["Draw"])
# Out:
# (232.75126088750295, 0.0)
