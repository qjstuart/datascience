# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
outlets = ["Shoreditch", "Hugo's Burger Bar", "New York Best", "Badass Burgers", "Homemade",
           " Club House", "Hard Rock", "Mojo's", "Sticky Fingers", "Hungry Cow"]

# %%
popularity_scores = [8, 3, 3, 6, 18, 2, 2, 10, 25, 2]
popularity_scores.sort(reverse = True) # Sort in descending order

# %%
# Function to display bar value on top each bar. This is done by positioning text above 
# each rectangle in the list of rectangles generated by matplotlib for the bar graph.
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + (rect.get_width()/2), (1.0*height), '%d' % int(height),
                ha='center', va='bottom')

# %%
fig, ax = plt.subplots(figsize=(15,9))
ax.set_title('Burger Outlets in Malta and Gozo by Popularity', fontsize = 20)
ax.tick_params(axis='x', rotation=20)
# ax.set_ylabel("Votes", fontsize=15)
rects = plt.bar(outlets, popularity_scores, color="orange")

# Set different bar color for Gozo
rects[5].set_color("firebrick")
rects[7].set_color("firebrick")

# Set legend
legend_elements = [Patch(facecolor='orange', label="Malta"), 
                   Patch(facecolor='firebrick', label="Gozo")]
ax.legend(handles=legend_elements)

autolabel(rects) # Include values on top of each bar
plt.savefig("./fig/Fixed_visualization_nogrid.png")
plt.show()
