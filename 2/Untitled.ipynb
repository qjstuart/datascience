# %%
import chess.pgn

# %%
pgn = open("caissabase.pgn")

# %%
# first_game = chess.pgn.read_game(pgn)
# str = first_game.headers["Result"]
# print(str[0])

vis = chess.pgn.GameBuilder()

# %%
white_wins = []
games = []
# for i in range(0,10):
# #     wins_list = [game for game in pgn if game.headers["Result"][0] == '0']
#     game = chess.pgn.read_game(pgn)
#     if (game.headers["Result"][0] == '0'):
#         games.append(game)

# go through headers based on some condition
for i in range(0,10):
    offset = pgn.tell()
    
    headers = chess.pgn.read_headers(pgn)
    if headers is None:
        break

    if headers["Result"][0] == '0':
        white_wins.append(offset)

for offset in white_wins:
    pgn.seek(offset)
    games.append(chess.pgn.read_game(pgn))
        
# for g in list:
#     print(g.headers["Result"])

# %%
test = [] # list I wish to append moves to (as strings)
game = chess.pgn.read_game(pgn)

board = game.board()

for move in game.mainline_moves():
    print(board.san(move))
    board.push(move)
#     test.append(board.san(move)) # this does not work

print(move)
# Out:
# e4
# c5
# Nf3
# d6
# d4
# cxd4
# Qxd4
# Nf6
# Bg5
# Nc6
# Bb5
# Bd7
# Qd3
# a6
# Bxc6
# Bxc6
# Nc3
# e6
# O-O-O
# Be7
# Nd4
# O-O
# f4
# h6
# h4
# Re8
# Kb1
# Qa5
# f5
# Bd7
# Bd2
# Qc7
# Qg3
# Kh7
# fxe6
# Bxe6
# Nxe6
# fxe6
# Qh3
# Bf8
# g4
# Nd7
# g5
# Ne5
# gxh6
# gxh6
# Ne2
# Bg7
# Nf4
# Rac8
# Bc3
# Nc4
# e5
# Qf7
# Qd3+
# Kg8
# Rhg1
# dxe5
# Rxg7+
# Qxg7
# Nh5
# Qf7
# Rg1+
# Kh8
# Rg6
# Qf8
# Rf6
# Rcd8
# Qe2
# Qxf6
# Nxf6
# Rf8
# b3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-eaf03008621e> in <module>
#       9 #     test.append(board.san(move)) # this does not work
#      10
# ---> 11 print(move[1])
#
# TypeError: 'Move' object is not subscriptable
